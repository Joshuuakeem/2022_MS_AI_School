# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
large_img = cv2.imread('ex_image.png')
watermark = cv2.imread('ex_image_logo.png')

small_img = cv2.resize(watermark, (300, 300))
cv2_imshow(small_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F4ECFD30EB0>
# -1

# %%
x_offset = 30
y_offset = 70

x_end = x_offset + small_img.shape[0]
y_end = y_offset + small_img.shape[1]

#crop = large_img[y_offset:y_end, x_offset:x_end]
large_img[y_offset:y_end, x_offset:x_end] = small_img
cv2_imshow(large_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x683 at 0x7F4EBE2850A0>
# -1
