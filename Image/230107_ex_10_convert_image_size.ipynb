# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
image_path = "./IU.jpg"
image = cv2.imread(image_path)
# image 10x10 픽셀 크기로 변환
image_color_10x10 = cv2.resize(image, (10, 10))
image_color_10x10.flatten()
cv2_imshow(image_color_10x10)

# image 225x255 픽셀 크기로 변환
image_color_225x255 = cv2.resize(image, (225, 255))
image_color_225x255.flatten()
cv2_imshow(image_color_225x255)

x = np.array([[51, 40], [14, 19], [10, 7]])
x = x.flatten()
print(x)
# Out:
# <PIL.Image.Image image mode=RGB size=10x10 at 0x7FCDDE8550A0>
# <PIL.Image.Image image mode=RGB size=225x255 at 0x7FCDDE855160>
# [51 40 14 19 10  7]
