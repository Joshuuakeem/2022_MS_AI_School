# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
image_path = "./car.png"
img = cv2.imread(image_path)

# 엠보싱 효과
filter1 = np.array([[0, 1, 0], [0, 0, 0], [0, -1, 0]])
filter2 = np.array([[-1, -1, 0], [-1, 0, 1], [0, 1, 1]])
emboss_img = cv2.filter2D(img, -1, filter2)
emboss_img = emboss_img + 128
cv2_imshow(emboss_img)
# Out:
# <PIL.Image.Image image mode=RGB size=960x640 at 0x7FCCD2B50C40>
