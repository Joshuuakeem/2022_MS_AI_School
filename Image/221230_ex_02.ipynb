# %%
# 가우시안 블러
import cv2
from google.colab.patches import cv2_imshow

# %%
image_path="./cat.png"

# %%
# 이미지 읽기
image = cv2.imread(image_path)

image_g_blury = cv2.GaussianBlur(image, (15,15), 0)
cv2_imshow(image_g_blury)
# Out:
# <PIL.Image.Image image mode=RGB size=600x399 at 0x7F9571465400>
