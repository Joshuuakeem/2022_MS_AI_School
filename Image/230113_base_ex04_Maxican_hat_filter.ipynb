# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
image = cv2.imread('./car.png')

# %%
# creating maxican hat filter for
filter = np.array([[0, 0, -1, 0, 0], [0, -1, -2, -1, 0],
                   [-1, -2, 16, -2, -1], [0, -1, -2, -1, 0],
                   [0, 0, -1, 0, 0]])
mexican_hat_image = cv2.filter2D(image, -1, filter)
cv2_imshow(mexican_hat_image)
# Out:
# <PIL.Image.Image image mode=RGB size=960x640 at 0x7F79D316E730>

# %%
# 3x3
filter = np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]])
mexican_hat_image = cv2.filter2D(image, -1, filter)
cv2_imshow(mexican_hat_image)
cv2.imwrite('./mexican_hat_5x5.png', mexican_hat_image)
# Out:
# <PIL.Image.Image image mode=RGB size=960x640 at 0x7F79D316E670>
# True
